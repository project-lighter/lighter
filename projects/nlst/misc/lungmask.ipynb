# %%
from lungmask import mask
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
input_image = sitk.ReadImage("/mnt/data1/NLST/nrrd/T0/100004_img.nrrd")
# segmentation = mask.apply_fused(input_image)
segmentation = mask.apply(input_image, batch_size=48)
# Out:
# ...
# 100%|██████████| 5/5 [00:00<00:00, 171.14it/s]

# %%
plt.imshow(segmentation[70])
plt.show()
plt.imshow(sitk.GetArrayFromImage(input_image)[70], cmap="gray")

# %%
input_image = sitk.ReadImage("/mnt/ibrahim/NLST/nrrd/lung_masks/T0/100004_img.nrrd")

# %%
plt.imshow(sitk.GetArrayFromImage(input_image)[70])
