# %%
import pandas as pd

# %%
nlst_labels = pd.read_csv("/media/ibro/data_1/NLST/NLST_clinical_whole.csv")
romans_labels = pd.read_csv("/media/ibro/data_1/NLST/SelectionTrainTestFinal.csv")
# Out:
# /tmp/ipykernel_1274427/1795782349.py:1: DtypeWarning: Columns (47,264,284,285,286,287,288,853,854,961,978,985) have mixed types. Specify dtype option on import or set low_memory=False.
#   nlst_labels = pd.read_csv("/media/ibro/data_1/NLST/NLST_clinical_whole.csv")

# %%
romans_labels
# Out:
#        Patient_ID Data_Set Source  T0  T1  T2  Death  LungCancer  ASCVD  \
# 0          100004     Tune    12k   1   1   0      0           0      0
# 1          100012    Train    3kc   1   1   0      0           1      0
# 2          100015    Train    12k   1   1   1      0           0      0
# 3          100019    Train    12k   1   1   1      0           0      0
# 4          100023     Test    12k   1   1   0      1           0      0
# ...           ...      ...    ...  ..  ..  ..    ...         ...    ...
# 14159      218882    Train    12k   1   1   0      0           0      0
# 14160      218890     Test    12k   1   1   0      0           0      0
# 14161      218892    Train    12k   1   1   1      0           0      0
# 14162      218893    Train    12k   1   1   1      0           0      0
# 14163      218894     Test    12k   1   1   1      0           0      0
#
#        Female  Event  age  height  marital  weight  cigsmok cen
# ...

# %%
for c in list(nlst_labels.columns):
    print(c)
# Out:
# pid
# finalgrouping
# days_t0tot1
# days_t1tot2
# scr_days0
# scr_days1
# scr_days2
# gender_mbs
# race_mbs
# cigsmok_mbs
# copd_mbs
# famhistory_mbs
# histology_mbs2
# stage_mbs
# histology_mbs
# screengroupt0
# screengroupt1
# screengroupt2
# fup_days
# candx_days
# death_days
# deathdays2
# deathmonths
# deathmonths2
# deathind
# deathtime5yr
# deathmonth5yr
# deathind5yr
# pfstime5yr
# pfsevent5yr
# pfstimemons5yr
# pfstimedays
# pfstimemons
# pfsevent
# cancyr
# gendertab1
# racetab1
# ethnictab1
# cigsmoktab1
# age_quit
# educattab1
# maritaltab1
# diagcopd2
# famhistory
# de_stagtab1
# histologydescription2
# age
# cctab5v1
# gendertab5
# racetab5
# cigsmoktab5
# packyear
# copdtab5
# famhistorytab5
# stagetab5
# histtab5
# treattab5
# treatdesc
# treatdescna
# stage2
# genderz
# can_scr
# canc_free_days
# first_lc1
# first_lc2
# first_lc3
# lc_order1
# lc_order2
# lc_order3
# educatz
# smokeage
# smokeday
# cigsmok
# gender
# rndgroup
# scr_lat0
# scr_lat1
# scr_lat2
# elig
# ...
